# %%
import pandas as pd

# %%
df_carteira_pf = pd.read_excel("./Files/Carteira_credito.xlsx")
df_carteira_pf
# Out:
#                                       Instituição         Código TCB TD  TC  \
# 0                         CAIXA ECONÔMICA FEDERAL         51.626  b1  C   1
# 1                                              BB         49.906  b1  C   1
# 2                                            ITAU         10.069  b1  C   2
# 3                                        BRADESCO         10.045  b1  C   2
# 4                                       SANTANDER         30.379  b1  C   3
# ...                                           ...            ...  .. ..  ..
# 4190                    UNICRED DTVM - PRUDENCIAL  1.000.088.187  n2  I   2
# 4191  F & F INSTITUICAO DE PAGAMENTO - PRUDENCIAL  1.000.088.273  n4  I   2
# 4192                    CLARO PAY IP - PRUDENCIAL  1.000.088.307  n4  I   3
# 4193                        LISTO IP - PRUDENCIAL  1.000.088.383  n4  I   3
# 4194                      PAY2ALL IP - PRUDENCIAL  1.000.088.479  n4  I   2
#
# ...

# %%
for cab, linha in df_carteira_pf.iterrows():
    if 'Total' in cab or 'Vencido a' in cab or 'A Vencer' in cab :
        df_carteira_pf.drop(linha)
